# %%
# 🎬 Movie Success Predictor – Data Exploration
# In this notebook, we perform initial data loading, merging, cleaning, 
# and exploratory data analysis (EDA) for building a machine learning model 
# to predict whether a movie will be a box-office success or not.

# %%
import pandas as pd
import numpy as np

# %%
import sys
import os

# %%
movies_df = pd.read_csv("../data/tmdb_5000_movies.csv")
credits_df = pd.read_csv("../data/tmdb_5000_credits.csv")

# %%
# df merging
merged_df = movies_df.merge(credits_df, left_on='id', right_on='movie_id', how='inner')
merged_df.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
# ...

# %%
# Add the path to the src/ directory
sys.path.append(os.path.abspath('../src'))

# %%
from preprocessing import clean_data
cleaned_df = clean_data(merged_df)
# Out:
# /Users/neenakhan/dev/Data Science/DS-Project/movie-success-predictor/src/preprocessing.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['overview'].fillna("No overview", inplace=True)
# /Users/neenakhan/dev/Data Science/DS-Project/movie-success-predictor/src/preprocessing.py:28: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# 4. Fill missing runtimes with median
median_runtime = cleaned_df['runtime'].median()
cleaned_df['runtime'].fillna(median_runtime, inplace=True)
# Out:
# /var/folders/0l/gw7rz2897zj89pkm41cpn3l40000gn/T/ipykernel_7877/3140412472.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cleaned_df['runtime'].fillna(median_runtime, inplace=True)

# %%
# 5. Rename 'title_x' to just 'title'
cleaned_df.rename(columns={'title_x': 'title'}, inplace=True)

# %%
cleaned_df.tail(2)
# Out:
#       budget                               genres      id  \
# 4801       0                                   []  126186
# 4802       0  [{"id": 99, "name": "Documentary"}]   25975
#
#                                                keywords original_language  \
# 4801                                                 []                en
# 4802  [{"id": 1523, "name": "obsession"}, {"id": 224...                en
#
#          original_title                                           overview  \
# 4801   Shanghai Calling  When ambitious New York attorney Sam is sent t...
# 4802  My Date with Drew  Ever since the second grade when he first saw ...
#
#       popularity                               production_companies  \
# 4801    0.857008                                                 []
# 4802    1.929883  [{"name": "rusty bear entertainment", "id": 87...
#
#                                    production_countries release_date  revenue  \
# ...

# %%
# Check duplicate data
# cleaned_df.duplicated().sum()
# cleaned_df['title'].duplicated().sum()

# %%
# saved the clean data
cleaned_df.to_csv('../data/cleaned_movies.csv', index=False)
